# %% [markdown]
# # Sanity check dataset
#
# Objetivo: verificar se a planilha `curation_pilot.csv` está legível, completa e coerente para começar a curadoria computacional.

# %%
import pandas as pd
from pathlib import Path

# %%
data_path = Path("../data/raw/curation_pilot.csv")

df = pd.read_csv(data_path)
df.head()

# %%
df.shape

# %%
df.columns.tolist()

# %%
df["train_eligible"].value_counts(dropna=False)

# %%
df["chemical_regime"].value_counts(dropna=False)

# %%
df["target_group"].value_counts(dropna=False)
